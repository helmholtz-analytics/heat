# %% [markdown]
# # Using Heat on Jupyter4NFDI
#
# This notebook is intended to show how to get started with Heat on Jupyter4NFDI. If you are not currently on Jupyter4NFDI, this notebook is probably not for you.
#
# If you are on Jupyter4NFDI: Welcome!
#
# Before we start with Heat, we go through a few Jupyter4NFDI related things.
# First, let's test the installation:

# %%
# %%bash
# mpirun -n 2 python -c "import heat as ht; x = ht.arange(9, split=0); print(f'Rank {ht.communication.MPI_WORLD.rank} has local shape {x.lshape} with global shape {x.shape}')"
# Out:
# Rank 0 has local shape (5,) with global shape (9,)
# Rank 1 has local shape (4,) with global shape (9,)

# %% [markdown]
# If the above cell ran successfully and produced some output, that's good!
#
# You need to be aware that Jupyter4NFDI has persistent storage and non-persistent storage.
# Your personal persistent storage is located at
# ```
# /home/jovyan/work
# ```
# Anything that you want to persist beyond this session, you need to store in that directory!
# Let's check which directory you are currently in:

# %%
# %%bash
# pwd
# Out:
# /Users/thomasbaumann/Documents/repositories/heat/tutorials

# %% [markdown]
# If you're running this notebook as intended, the above cell should return a path outside of your persistent storage.
#
# If this is your first time here, please copy the tutorials to your persistent storage using the following command.
# If you were here before, skip this step in order not to overwrite anything!

# %%
# %%bash
# cp -r ../doc/source/tutorials/notebooks/ ../work/heat_tutorial_notebooks

# %% [markdown]
# In this directory, you will find instructions for setup on various environments before starting the tutorials.
# On Jupyter4NFDI, you need to start an IPyParallel environment just like you would locally.
#
# To this end, please open a new tab (click on the big blue + button in the top left corner), select `Terminal` and run the following bash command in the shell you just opened
# ```bash
# ipcluster start -n 4 --engines=mpi
# ```

# %% [markdown]
# Now, please navigate to `../work_heat_tutorial_notebooks` in the file browser to the left and get going!
# In this directory, you will find a `README.md` file that will tell you how to get started.
# Note that you can skip the environment setup section because you already did that in the previous cell.
#
# If you come back to Jupyter4NFDI later on, you will again land in this notebook.
# You need to start the IPyParallel environment every time, but that's all!

# %% [markdown]
# Please note that the tutorials are work in progress.
# They have been developed to run on Jülich HPC machines are not necessarily fully supported on Jupyter4NFDI yet.
# We appreciate your patience and hope you learn what you need regarless!

# %% [markdown]
# # Using Heat on Jupyter4NFDI
#
# This notebook is intended to show how to get started with Heat on Jupyter4NFDI. If you are not currently on Jupyter4NFDI, this notebook is probably not for you.
#
# If you are on Jupyter4NFDI: Welcome!
#
# The first step is to test the installation:

# %%
# %%bash
# mpirun -n 2 python -c "import heat as ht; x = ht.arange(10, split=0); print(f'Rank {ht.communication.MPI_SELF.rank} local shape: {x.lshape}')"

# %% [markdown]
# If the above cell ran successfully, that's good!
#
# You need to be aware that Jupyter4NFDI has persistent storage and non-persistent storage.
# Your personal persistent storage is located at
# ```
# /home/jovyan/work
# ```
# Anything that you want to persist beyond this session, you need to store in that directory!
# Let's check which directory you are currently in:

# %%
# %%bash
# pwd

# %% [markdown]
# If this is your first time here, please copy the tutorials to your persistent storage using the following command.
# If you were here before, skip this step in order not to overwrite anything!

# %%
# %%bash
# cp -r ../doc/source/tutorials/notebooks/ ../work/heat_tutorial_notebooks

# %% [markdown]
# In this directory, you will find instructions for setup before starting the tutorials.
# You can simply follow the instructions for local setup as Jupyter4NFDI behaves very similar to how your laptop would.
#
# The setup you need is to start an IPyParallel environment, which you can do using the bash command
# ```bash
# ipcluster start -n 4 --engines=mpi
# ```
# You can run it here by executing the following cell, but be aware that this will block this notebook and keep printing output.
# So make sure you are done here and know how to continue before executing the following cell

# %%
# %%bash
# ipcluster start -n 4 --engines=mpi &

# %% [markdown]
# Now, please navigate to `../work_heat_tutorial_notebooks` and get going!
# In this directory, you will find a `README.md` file that will tell you how to get started.
